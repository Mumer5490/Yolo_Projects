# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## importing required libraries
import os
import shutil
import random

# %%
# %cd "/content/drive/MyDrive/data"
# %cd "/content/drive/MyDrive/yolo8_with_Tfilte"
# Out:
# /content/drive/MyDrive/yolo8_with_Tfilte

# %%
# !gdown "1GGx6A3wwg0GqNUTQZrqoKKGwtgYLgX1h"
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1GGx6A3wwg0GqNUTQZrqoKKGwtgYLgX1h
# From (redirected): https://drive.google.com/uc?id=1GGx6A3wwg0GqNUTQZrqoKKGwtgYLgX1h&confirm=t&uuid=386df713-8223-4b96-a36e-704573516a7e
# To: /content/drive/MyDrive/data/red_chilli_new.zip
# 100% 92.0M/92.0M [00:02<00:00, 31.2MB/s]

# %%
# !unzip "/content/drive/MyDrive/yolo8_with_Tfilte/red_chilli_new.zip"
# Out:
# Archive:  /content/drive/MyDrive/yolo8_with_Tfilte/red_chilli_new.zip
#    creating: red_chilli_new/
#   inflating: red_chilli_new/data.yaml
#    creating: red_chilli_new/test/
#    creating: red_chilli_new/test/images/
#   inflating: red_chilli_new/test/images/-1-_jpg.rf.ec9ef78e8a32a8a8a580f6ab7107b88c - Copy (2) - Copy.jpg
#   inflating: red_chilli_new/test/images/-1-_jpg.rf.ec9ef78e8a32a8a8a580f6ab7107b88c - Copy (2).jpg
#   inflating: red_chilli_new/test/images/-1-_jpg.rf.ec9ef78e8a32a8a8a580f6ab7107b88c - Copy (3).jpg
#   inflating: red_chilli_new/test/images/-1-_jpg.rf.ec9ef78e8a32a8a8a580f6ab7107b88c - Copy - Copy (2).jpg
#   inflating: red_chilli_new/test/images/-1-_jpg.rf.ec9ef78e8a32a8a8a580f6ab7107b88c - Copy - Copy - Copy.jpg
#   inflating: red_chilli_new/test/images/-1-_jpg.rf.ec9ef78e8a32a8a8a580f6ab7107b88c - Copy - Copy.jpg
#   inflating: red_chilli_new/test/images/-1-_jpg.rf.ec9ef78e8a32a8a8a580f6ab7107b88c - Copy.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 873.3/873.3 kB 49.5 MB/s eta 0:00:00
# ...

# %%
# !yolo train model=yolov8n.pt data="/content/red_chilli_new/data.yaml" epochs=100 imgsz=640 patience=20
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 376MB/s]
# Ultralytics YOLOv8.2.96 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo export model="/content/runs/detect/train/weights/best.pt" format=tflite
# Out:
# Ultralytics YOLOv8.2.96 🚀 Python-3.10.12 torch-2.4.0+cu121 CPU (Intel Xeon 2.00GHz)
# Model summary (fused): 168 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/content/runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (6.0 MB)
# requirements: Ultralytics requirements ['sng4onnx>=1.0.1', 'onnx_graphsurgeon>=0.3.26', 'onnx>=1.12.0', 'onnx2tf>1.17.5,<=1.22.3', 'onnxslim>=0.1.31', 'tflite_support', 'onnxruntime'] not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.6/136.6 kB 55.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 197.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 276.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.0/435.0 kB 365.0 MB/s eta 0:00:00
# ...
