# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## importing required libraries
import os
import shutil
import random

# %%
# %cd "/content/drive/MyDrive/data"
# Out:
# /content/drive/MyDrive/data

# %%
# !gdown "1GGx6A3wwg0GqNUTQZrqoKKGwtgYLgX1h"
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1GGx6A3wwg0GqNUTQZrqoKKGwtgYLgX1h
# From (redirected): https://drive.google.com/uc?id=1GGx6A3wwg0GqNUTQZrqoKKGwtgYLgX1h&confirm=t&uuid=9cf2ab7f-de97-4450-975f-682249dbb12f
# To: /content/drive/MyDrive/data/red_chilli_new.zip
# 100% 92.0M/92.0M [00:02<00:00, 33.0MB/s]

# %%
# !unzip "/content/drive/MyDrive/data/red_chilli_new.zip"
# Out:
# Archive:  /content/drive/MyDrive/data/red_chilli_new.zip
#    creating: red_chilli_new/
#   inflating: red_chilli_new/data.yaml
#    creating: red_chilli_new/test/
#    creating: red_chilli_new/test/images/
#   inflating: red_chilli_new/test/images/-1-_jpg.rf.ec9ef78e8a32a8a8a580f6ab7107b88c - Copy (2) - Copy.jpg
#   inflating: red_chilli_new/test/images/-1-_jpg.rf.ec9ef78e8a32a8a8a580f6ab7107b88c - Copy (2).jpg
#   inflating: red_chilli_new/test/images/-1-_jpg.rf.ec9ef78e8a32a8a8a580f6ab7107b88c - Copy (3).jpg
#   inflating: red_chilli_new/test/images/-1-_jpg.rf.ec9ef78e8a32a8a8a580f6ab7107b88c - Copy - Copy (2).jpg
#   inflating: red_chilli_new/test/images/-1-_jpg.rf.ec9ef78e8a32a8a8a580f6ab7107b88c - Copy - Copy - Copy.jpg
#   inflating: red_chilli_new/test/images/-1-_jpg.rf.ec9ef78e8a32a8a8a580f6ab7107b88c - Copy - Copy.jpg
#   inflating: red_chilli_new/test/images/-1-_jpg.rf.ec9ef78e8a32a8a8a580f6ab7107b88c - Copy.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.3/721.3 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 36.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 48.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 34.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 885.5 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 2.2 MB/s eta 0:00:00
# ...

# %%
# !yolo train model=yolov8n.pt data="/content/drive/MyDrive/data/red_chilli_new/data.yaml" epochs=100 imgsz=640 patience=20
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 59.1MB/s]
# Ultralytics YOLOv8.1.28 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ### Training the model

# %% [markdown]
# ## Analysing the results using tensorboard

# %%
from time import time
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

model = torch.hub.load("ultralytics/yolov5", 'custom', path='/content/yolov5/runs/train/exp2/weights/best.pt', force_reload=True)

cap = cv2.VideoCapture(0)
while cap.isOpened():
    start = time()
    ret, frame = cap.read()
    if not ret:
        break

    result = model(frame)

    cv2.imshow('Screen', np.squeeze(result.render()))
    if cv2.waitKey(10) & 0xff == ord('x'):
        break
    if cv2.getWindowProperty("Screen", cv2.WND_PROP_VISIBLE) < 1:
        break

    end = time()
    fps = 1 / (end - start)
    print(fps)

cap.release()
cv2.destroyAllWindows()
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 2024-2-19 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %% [markdown]
# ### inference or detection on new images

# %% [markdown]
# ### display result images

# %%
# !yolo detect predict model="/content/drive/MyDrive/data/runs/detect/train/weights/best.pt" source="/content/drive/MyDrive/data/red_chilli_new/test/images"
# Out:
# Ultralytics YOLOv8.1.28 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/544 /content/drive/MyDrive/data/red_chilli_new/test/images/-1-_jpg.rf.ec9ef78e8a32a8a8a580f6ab7107b88c - Copy (2).jpg: 640x640 1 Red Chili, 363.8ms
# image 2/544 /content/drive/MyDrive/data/red_chilli_new/test/images/-1-_jpg.rf.ec9ef78e8a32a8a8a580f6ab7107b88c - Copy (3).jpg: 640x640 1 Red Chili, 227.3ms
# image 3/544 /content/drive/MyDrive/data/red_chilli_new/test/images/-1-_jpg.rf.ec9ef78e8a32a8a8a580f6ab7107b88c - Copy - Copy (2).jpg: 640x640 1 Red Chili, 239.2ms
# image 4/544 /content/drive/MyDrive/data/red_chilli_new/test/images/-1-_jpg.rf.ec9ef78e8a32a8a8a580f6ab7107b88c - Copy - Copy - Copy.jpg: 640x640 1 Red Chili, 227.3ms
# image 5/544 /content/drive/MyDrive/data/red_chilli_new/test/images/-1-_jpg.rf.ec9ef78e8a32a8a8a580f6ab7107b88c - Copy - Copy.jpg: 640x640 1 Red Chili, 265.9ms
# ...
